# %% [markdown]
# Менчиков Алексей Леонидович
# М8О-105М-23
#
# **Вариант 10**
#
# <2, 6>, <2, 5>, <4, 3>, <7, 2>

# %%
from Convolution import Convolution

x_test = [2, 2, 4, 7]
y_test = [6, 5, 3, 2]

lab = Convolution(x=x_test, y=y_test)
lab.solveLab()
# Out:
# Аддитивная свертка
# A = 73
# B = 15
# C = 48
# D = 16
# k = -0.7164179104477612
# b = 6.686567164179104
# k_1 = 0.4173913043478261
# k_2 = 0.582608695652174
# MSE: 0.3507462686567163
# Свертка с неравными степенями переменных
# A = 2689
# B = 73
# C = 190
# D = 16
# k = 0.07517965726920951
# b = 5.372028745163074
# k_1 = 0.06992287917737788
# k_2 = 0.9300771208226221
# MSE: 0.5829187396351578
# Мультипликативная свертка
# A = 6.66928439170568
# B = 4.718498871295094
# C = 5.229332529905282
# D = 5.19295685089021
# k = -0.8125328175258343
# b = 2.256723008319021
# k_1 = 0.44828585152734934
# k_2 = 0.5517141484726508
# MSE: 0.1295226373547472
# Из трех рассмотренных сверток в данном примере следует выбрать
# мультипликативную свертку:
# k1 = 0.45, k2 = 0.58
# a_0 = <3, 3>, u_0 = 3.1
# a_1 = <4, 2>, u_1 = 2.8
# a_2 = <7, 4>, u_2 = 5.4
# a_3 = <5, 2>, u_3 = 3.1
# a_4 = <2, 2>, u_4 = 2.0
# a_5 = <4, 5>, u_5 = 4.8
# a_2 > a_5 > a_0 > a_3 > a_1 > a_4
